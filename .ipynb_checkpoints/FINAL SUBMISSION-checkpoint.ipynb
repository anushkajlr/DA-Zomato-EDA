# %% [markdown]
# # DATA CLEANING AND EDA

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # READING THE CSV FILE

# %%
df_zomato = pd.read_csv("zomato.csv")
df_zomato.head()
df_zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
#  13  reviews_list                 51717 non-null  object
#  14  menu_item                    51717 non-null  object
#  15  listed_in(type)              51717 non-null  object
#  16  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 6.7+ MB

# %%
df_zomato.shape
# Out:
# (51717, 17)

# %% [markdown]
# IT CAN BE OBSERVED MANY ATTRIBUTES HAVE MISSING VALUES

# %% [markdown]
# Dish liked has the most null attributes
# not a good idea to use it for analysis of ALL restaurants

# %%
df_zomato[["dish_liked"]]
# Out:
#                                               dish_liked
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
# [51717 rows x 1 columns]

# %%
df_zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
#Dropping Columns not needed at the moment
df_zomato = df_zomato.drop(['url','phone'],axis = 1)
df_zomato.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
#Removing all duplicate valuesdf_zomato.drop_duplicates(inplace = True)

# %%
df_zomato.drop_duplicates(inplace = True)
df_zomato.shape
# Out:
# (51674, 15)

# %% [markdown]
# THIS HOWEVER DOES NOT TAKE CARE OF REMOVAL OF RESTAURANTS WITH SAME NAME

# %%
example = df_zomato[df_zomato['name'] == 'Jalsa']
example
# Out:
#                                                  address   name online_order  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 456    942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 559    942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 2488   942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 2966   942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 3462   942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 7607   25/7, Doddannakundi, Outer Ring Road, Mahadeva...  Jalsa          Yes
# 19401  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 20399  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 21302  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 41364  25/7, Doddannakundi, Outer Ring Road, Mahadeva...  Jalsa          Yes
#
#       book_table    rate  votes      location      rest_type  \
# 0            Yes   4.1/5    775  Banashankari  Casual Dining
# 456          Yes   4.1/5    775  Banashankari  Casual Dining
# 559          Yes   4.1/5    775  Banashankari  Casual Dining
# 2488         Yes   4.1/5    775  Banashankari  Casual Dining
# 2966         Yes   4.1/5    775  Banashankari  Casual Dining
# 3462         Yes  4.1 /5    804  Banashankari  Casual Dining
# 7607         Yes   4.2/5   2173  Marathahalli  Casual Dining
# 19401        Yes   4.1/5    783  Banashankari  Casual Dining
# 20399        Yes   4.1/5    783  Banashankari  Casual Dining
# 21302        Yes  4.1 /5    783  Banashankari  Casual Dining
# 41364        Yes  4.2 /5   2189  Marathahalli  Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 456    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 559    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 2488   Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 2966   Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 3462   Pasta, Lunch Buffet, Paneer Lajawab, Masala Pa...
# 7607   Mutton Curry, Stuffed Mushroom, Laccha Paratha...
# 19401  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 20399  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 21302  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 41364  Mutton Curry, Stuffed Mushroom, Laccha Paratha...
#
#                              cuisines approx_cost(for two people)  \
# 0      North Indian, Mughlai, Chinese                         800
# 456    North Indian, Mughlai, Chinese                         800
# 559    North Indian, Mughlai, Chinese                         800
# 2488   North Indian, Mughlai, Chinese                         800
# 2966   North Indian, Mughlai, Chinese                         800
# 3462   North Indian, Mughlai, Chinese                         800
# 7607            North Indian, Mughlai                       1,500
# 19401  North Indian, Mughlai, Chinese                         800
# 20399  North Indian, Mughlai, Chinese                         800
# 21302  North Indian, Mughlai, Chinese                         800
# 41364           North Indian, Mughlai                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 456    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 559    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 2488   [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 2966   [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 3462   [('Rated 4.0', 'RATED\n  Super ambience\nGreat...        []
# 7607   [('Rated 4.0', 'RATED\n  A pretty decent place...        []
# 19401  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 20399  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 21302  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 41364  [('Rated 4.0', 'RATED\n  Friendly staff, avera...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 456          Delivery    Banashankari
# 559          Dine-out    Banashankari
# 2488           Buffet    Basavanagudi
# 2966         Delivery    Basavanagudi
# 3462         Dine-out    Basavanagudi
# 7607         Delivery     Brookefield
# 19401          Buffet       Jayanagar
# 20399        Delivery       Jayanagar
# 21302        Dine-out       Jayanagar
# 41364        Delivery    Marathahalli

# %% [markdown]
# DIFFERENCE IS THE LISTED IN TYPE AND LISTED IN CITY REST ALL VALUES THE SAME
# Will decide whether to club or keep as is depending in criterion for the model chosen

# %% [markdown]
# # OBSERVING ONLINE ORDER RATIO

# %%
k = df_zomato.groupby(['online_order']).size().plot(kind='pie', title = 'online ordering')

# %%
k = df_zomato.groupby(['book_table']).size().plot(kind='pie', title = 'book table')

# %%
k = df_zomato.groupby(['listed_in(city)']).size().plot(kind='bar', title = 'book table')
#btm layout has max number of restaurants

# %%
k = df_zomato.groupby(['listed_in(type)']).size().plot(kind='bar', title = 'book table')
#delivery takes the lead in modern bangalore

# %%
#now i will try to get the number of high rated restaurants in bangalore grouped by area
#first i will clean the rating column
df_zomato['rate'].isnull().sum()
# Out:
# 7767

# %%
#7767 vlaues have been left null

# %%
#will see number of null values
#convert all null to 0
#then see if 0 and null are equal
#df_zomato['rate'].fillna(0, inplace = True)

# %%
#upon working on rate column pbserved that data has characters like /
df_zomato['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
def handlerate(value):
    if value=='-' or value == 'NEW':
        return np.nan

    else:
        value = str(value).split('/')
        value = value[0]
        return float(value)
    
df_zomato['rate'] = df_zomato['rate'].apply(handlerate)

# %%
df_zomato['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51674, dtype: float64

# %%
df_zomato['rate'].isnull().sum()
# Out:
# 10036

# %%
#koramangala 7th block has the highest rated restaurants
#now we can analyse the costs of restaurants in bangalore
df_zomato['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', nan, '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
def handlecomma(value):
    value = str(value)
    if ',' in value:
        value = value.replace(',', '')
        return float(value)
    else:
        return float(value)
    
df_zomato['approx_cost(for two people)'] = df_zomato['approx_cost(for two people)'].apply(handlecomma)
df_zomato['approx_cost(for two people)'].unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         900.,  200.,  750.,  150.,  850.,  100., 1200.,  350.,  250.,
#         950., 1000., 1500., 1300.,  199.,   80., 1100.,  160., 1600.,
#         230.,  130.,   50.,  190., 1700.,   nan, 1400.,  180., 1350.,
#        2200., 2000., 1800., 1900.,  330., 2500., 2100., 3000., 2800.,
#        3400.,   40., 1250., 3500., 4000., 2400., 2600.,  120., 1450.,
#         469.,   70., 3200.,   60.,  560.,  240.,  360., 6000., 1050.,
#        2300., 4100., 5000., 3700., 1650., 2700., 4500.,  140.])

# %%
df_zomato['approx_cost(for two people)'].min()
# Out:
# 40.0

# %%
df_zomato['approx_cost(for two people)'].max()
# Out:
# 6000.0

# %% [markdown]
# # SEEING DISTRIBUTION OF HIGH RATED RESTAURANTS

# %%
df_high = df_zomato.query('rate > 4')

# %%
k = df_high.groupby(['listed_in(city)']).size().plot(kind='bar', title = 'book table')

# %% [markdown]
# # Cost VS Rating Scatterplot for predicting correlation

# %%
cost_dist=df_zomato[['rate','approx_cost(for two people)','online_order']].dropna(axis = 0,how = "any")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
sns.scatterplot(x="rate",y='approx_cost(for two people)',hue='online_order',data=cost_dist)
plt.show()

# %% [markdown]
# ### Explantory variable: Rating
# ### Response variable: Cost

# %%
xarr=cost_dist['rate'].to_numpy()
yarr=cost_dist['approx_cost(for two people)'].to_numpy()

# %% [markdown]
# ### Calculating persons moment correlation coefficient

# %%
R = np.corrcoef(xarr, yarr)
print(R[0,1])
# Out:
# 0.3850604365893679

# %% [markdown]
# ### Since R > 0 we can say that rate and cost are positively correlated YET there are no definitive results

# %%
df_zomato['rest_type'].value_counts()
# Out:
# Quick Bites                   19114
# Casual Dining                 10322
# Cafe                           3730
# Delivery                       2600
# Dessert Parlor                 2263
#                               ...
# Dessert Parlor, Food Court        2
# Cafe, Food Court                  2
# Pop Up                            2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: rest_type, Length: 93, dtype: int64

# %% [markdown]
# # Cleaning cuisines model

# %%
cuisines = df_zomato['cuisines'].value_counts(ascending  = False)


cuisines_lessthan100 = cuisines[cuisines<100]



def handle_cuisines(value):
    if(value in cuisines_lessthan100):
        return 'others'
    else:
        return value
        
df_zomato['cuisines'] = df_zomato['cuisines'].apply(handle_cuisines)
df_zomato['cuisines'].value_counts()
# Out:
# others                                 26440
# North Indian                            2912
# North Indian, Chinese                   2381
# South Indian                            1826
# Biryani                                  917
#                                        ...
# South Indian, Chinese, North Indian      105
# Italian, Pizza                           105
# North Indian, Mughlai, Chinese           104
# South Indian, Fast Food                  104
# North Indian, Chinese, Seafood           102
# Name: cuisines, Length: 70, dtype: int64

# %% [markdown]
# ### Plotting the Correlation Matrix

# %%
df2= df_zomato
df2.dropna(how='any',inplace=True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23248 entries, 0 to 51715
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      23248 non-null  object
#  1   name                         23248 non-null  object
#  2   online_order                 23248 non-null  object
#  3   book_table                   23248 non-null  object
#  4   rate                         23248 non-null  float64
#  5   votes                        23248 non-null  int64
#  6   location                     23248 non-null  object
#  7   rest_type                    23248 non-null  object
#  8   dish_liked                   23248 non-null  object
#  9   cuisines                     23248 non-null  object
#  10  approx_cost(for two people)  23248 non-null  float64
#  11  reviews_list                 23248 non-null  object
#  12  menu_item                    23248 non-null  object
#  13  listed_in(type)              23248 non-null  object
#  14  listed_in(city)              23248 non-null  object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 2.8+ MB

# %%
#Encode the input Variables 
def Encode(zomato): 
    for column in zomato.columns[~zomato.columns.isin(['rate', 'approx_cost(for two people)', 'votes'])]:
        zomato[column] = zomato[column].factorize()[0] 
    return zomato
                     
zomato_en = Encode(df2.copy())

# %%
corr=zomato_en.corr(method='kendall')
plt.figure(figsize=(15,9))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### The highest spurious correlation is between review_list and listed_in(city) = 0.74
# #### book_table and approx_cost(for 2 people) is negatively correlated= -0.52
# #### Restaurants which provide an option of booking table in advance has a high average cost.

# %%
plt_1 = plt.figure(figsize=(10, 10))
sns.boxplot(x='book_table',y='approx_cost(for two people)',palette="Set2",data=zomato_en)
plt.xlabel('Book table facilty',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.title('Effect of book table option on restaurants price',fontsize=20)
plt.show()

# %% [markdown]
# #### Green box plot for restaurants that provide online booking facility
# #### Orange plot for restaurants that do not provide online booking facility

# %%
from sklearn.feature_extraction.text import CountVectorizer
def get_top_words(column, top_nu_of_words, nu_of_word):
    
    vec = CountVectorizer(ngram_range= nu_of_word, stop_words='english')
    
    bag_of_words = vec.fit_transform(column)
    
    sum_words = bag_of_words.sum(axis=0)
    
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    
    return words_freq[:top_nu_of_words]

# %%
# Top 15 two word frequencies for Cuisines
lst = get_top_words(df_zomato['cuisines'], 15, (2,2))
df_words = pd.DataFrame(lst, columns=['Word', 'Count'])
plt.figure(figsize=(7,6))
sns.barplot(data=df_words, x='Count', y='Word')
plt.title('Word Couple Frequency for Cuisines');

# %% [markdown]
# ### Thus from the above graph we conclude that north indiam is the most popular cuisine in bangalore

# %% [markdown]
# # CONTENT BASED MODEL FOR RECOMMENDATION OF SIMILIAR RESTAURANTS

# %% [markdown]
# # CLEANING THE REVIEWS COLUMN

# %%
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import re

# %%
# REPEATED RESTAURANTS HAVE THE SAME RATING WHEN THEY ARE PRESENT IN THE SAME AREA

# %% [markdown]
# # PREPROCESSING THE REVIEWS

# %%
#Applying the most basic methods first

# %% [markdown]
# # can do semantic ananlysis of reviews to ensure that the restaurant is liked by the users as well

# %%
## Lower Casing

df_zomato["reviews_list"] = df_zomato["reviews_list"].str.lower()

## Removal of Puctuations
import string
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))
df_zomato["reviews_list"] = df_zomato["reviews_list"].apply(lambda text: remove_punctuation(text))

# Removal of Stopwords
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])
df_zomato["reviews_list"] = df_zomato["reviews_list"].apply(lambda text: remove_stopwords(text))

#Cleaning URL
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)
df_zomato["reviews_list"] = df_zomato["reviews_list"].apply(lambda text: remove_urls(text))

# %%
df_zomato[df_zomato['address'] == '942, 21st Main Road, 2nd Stage, Banashankari, Bangalore']
# Out:
#                                                  address   name online_order  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 456    942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 559    942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 2488   942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 2966   942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 3462   942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 19401  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 20399  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
# 21302  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
#
#       book_table  rate  votes      location      rest_type  \
# 0            Yes   4.1    775  Banashankari  Casual Dining
# 456          Yes   4.1    775  Banashankari  Casual Dining
# 559          Yes   4.1    775  Banashankari  Casual Dining
# 2488         Yes   4.1    775  Banashankari  Casual Dining
# 2966         Yes   4.1    775  Banashankari  Casual Dining
# 3462         Yes   4.1    804  Banashankari  Casual Dining
# 19401        Yes   4.1    783  Banashankari  Casual Dining
# 20399        Yes   4.1    783  Banashankari  Casual Dining
# 21302        Yes   4.1    783  Banashankari  Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 456    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 559    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 2488   Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 2966   Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 3462   Pasta, Lunch Buffet, Paneer Lajawab, Masala Pa...
# 19401  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 20399  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 21302  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
#
#                              cuisines  approx_cost(for two people)  \
# 0      North Indian, Mughlai, Chinese                        800.0
# 456    North Indian, Mughlai, Chinese                        800.0
# 559    North Indian, Mughlai, Chinese                        800.0
# 2488   North Indian, Mughlai, Chinese                        800.0
# 2966   North Indian, Mughlai, Chinese                        800.0
# 3462   North Indian, Mughlai, Chinese                        800.0
# 19401  North Indian, Mughlai, Chinese                        800.0
# 20399  North Indian, Mughlai, Chinese                        800.0
# 21302  North Indian, Mughlai, Chinese                        800.0
#
#                                             reviews_list menu_item  \
# 0      rated 40 ratedn beautiful place dine inthe int...        []
# 456    rated 40 ratedn beautiful place dine inthe int...        []
# 559    rated 40 ratedn beautiful place dine inthe int...        []
# 2488   rated 40 ratedn beautiful place dine inthe int...        []
# 2966   rated 40 ratedn beautiful place dine inthe int...        []
# 3462   rated 40 ratedn super ambiencengreat food spic...        []
# 19401  rated 40 ratedn beautiful place dine inthe int...        []
# 20399  rated 40 ratedn beautiful place dine inthe int...        []
# 21302  rated 40 ratedn beautiful place dine inthe int...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 456          Delivery    Banashankari
# 559          Dine-out    Banashankari
# 2488           Buffet    Basavanagudi
# 2966         Delivery    Basavanagudi
# 3462         Dine-out    Basavanagudi
# 19401          Buffet       Jayanagar
# 20399        Delivery       Jayanagar
# 21302        Dine-out       Jayanagar

# %%
df_zomato.shape
df_zomato = df_zomato.drop_duplicates(['address','name'],keep = 'last')
df_zomato.shape
#one address we want only one restaurant since the values are anyway the same
# Out:
# (4615, 15)

# %%
df_zomato[df_zomato['address'] == '942, 21st Main Road, 2nd Stage, Banashankari, Bangalore']
# Out:
#                                                  address   name online_order  \
# 21302  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
#
#       book_table  rate  votes      location      rest_type  \
# 21302        Yes   4.1    783  Banashankari  Casual Dining
#
#                                               dish_liked  \
# 21302  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
#
#                              cuisines  approx_cost(for two people)  \
# 21302  North Indian, Mughlai, Chinese                        800.0
#
#                                             reviews_list menu_item  \
# 21302  rated 40 ratedn beautiful place dine inthe int...        []
#
#       listed_in(type) listed_in(city)
# 21302        Dine-out       Jayanagar

# %%
#type of restaurant will deal with later -- maybe come up with a list and replace the value

# %%
df_zomato
# Out:
#                                                  address  \
# 48     179, 1st Floor, Jawarlalnehru Road, BEML Layou...
# 152    100 Feet Ring Road, 2nd Phase, Banashankari, B...
# 190    1424, 14th Main Road, 1st Stage, Kumaraswamy L...
# 229    173, DSI college Road, Kumaraswamy Layout, Ban...
# 282    287, 1st Floor, 7th Block, 100 Feet Ring Road,...
# ...                                                  ...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 48                                         Beijing Bites          Yes
# 152                                     BOX8- Desi Meals          Yes
# 190                                        Just Shawarma          Yes
# 229                              Biggies Burger 'n' More          Yes
# 282                             Mojo Pizza - 2X Toppings          Yes
# ...                                                  ...          ...
# 51705                                 Izakaya Gastro Pub          Yes
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 51708                             Keys Cafe - Keys Hotel           No
# 51711                                            Bhagini           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table  rate  votes                    location           rest_type  \
# 48            No   3.7    679        Rajarajeshwari Nagar       Casual Dining
# 152           No   4.1    340                Banashankari  Takeaway, Delivery
# 190           No   3.9    160          Kumaraswamy Layout         Quick Bites
# 229           No   3.6     58          Kumaraswamy Layout         Quick Bites
# 282           No   4.2    179                Banashankari            Delivery
# ...          ...   ...    ...                         ...                 ...
# 51705        Yes   3.8    128                  Whitefield  Bar, Casual Dining
# 51707         No   3.9     77                  Whitefield    Fine Dining, Bar
# 51708         No   2.8    161                  Whitefield  Casual Dining, Bar
# 51711         No   2.5     81                  Whitefield  Casual Dining, Bar
# 51715        Yes   4.3    236  ITPL Main Road, Whitefield                 Bar
#
#                                               dish_liked       cuisines  \
# 48     Momos, Dragon Chicken, Hakka Noodles, Chowmein...  Chinese, Thai
# 152    Paratha, Mughlai Chicken, Masala Lemonade, But...         others
# 190                           Whole Meat Shawarma, Fries        Arabian
# 229               Burgers, Fries, Mojito, Chicken Burger         others
# 282    Veggie Pizza, Garlic Bread, Lava Cake, Chocola...          Pizza
# ...                                                  ...            ...
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...         others
# 51707                                   Rooftop Ambience    Finger Food
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...         others
# 51711                               Biryani, Andhra Meal         others
# 51715                       Cocktails, Pizza, Buttermilk    Finger Food
#
#        approx_cost(for two people)  \
# 48                           850.0
# 152                          500.0
# 190                          300.0
# 229                          650.0
# 282                          600.0
# ...                            ...
# 51705                       1200.0
# 51707                       2000.0
# 51708                       1200.0
# 51711                        800.0
# 51715                       2500.0
#
#                                             reviews_list menu_item  \
# 48     rated 30 ratedn iãx83ãx83ãx82ãx82ãx83ãx8...        []
# 152    rated 40 ratedn recently one industrial visit ...        []
# 190    rated 40 ratedn small place sharma delicious t...        []
# 229    rated 50 ratedn potato crunch burger biggies c...        []
# 282    rated 50 ratedn delivery time even rush hoursn...        []
# ...                                                  ...       ...
# 51705  rated 30 ratedn nice place hangout kids one pa...        []
# 51707  rated 40 ratedn went post dinner dessert smoot...        []
# 51708  rated 30 ratedn place good great food good spi...        []
# 51711  rated 40 ratedn fine place chill office hours ...        []
# 51715  rated 40 ratedn nice friendly place staff awes...        []
#
#       listed_in(type) listed_in(city)
# 48           Delivery    Banashankari
# 152          Delivery    Banashankari
# 190          Delivery    Banashankari
# 229          Delivery    Banashankari
# 282          Delivery    Banashankari
# ...               ...             ...
# 51705   Pubs and bars      Whitefield
# 51707   Pubs and bars      Whitefield
# 51708   Pubs and bars      Whitefield
# 51711   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
#
# [4615 rows x 15 columns]

# %%
df_zomato.set_index('name', inplace=True)
indices = pd.Series(df_zomato.index)

# %%
df_zomato
# Out:
#                                                                                               address  \
# name
# Beijing Bites                                       179, 1st Floor, Jawarlalnehru Road, BEML Layou...
# BOX8- Desi Meals                                    100 Feet Ring Road, 2nd Phase, Banashankari, B...
# Just Shawarma                                       1424, 14th Main Road, 1st Stage, Kumaraswamy L...
# Biggies Burger 'n' More                             173, DSI college Road, Kumaraswamy Layout, Ban...
# Mojo Pizza - 2X Toppings                            287, 1st Floor, 7th Block, 100 Feet Ring Road,...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# M Bar - Bengaluru Marriott Hotel Whitefield         Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# Keys Cafe - Keys Hotel                              Keys Hotel, 6, 1st Phase Industrial Area, Near...
# Bhagini                                             139/C1, Next To GR Tech Park, Pattandur Agraha...
# Chime - Sheraton Grand Bengaluru Whitefield Hot...  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                    online_order book_table  \
# name
# Beijing Bites                                               Yes         No
# BOX8- Desi Meals                                            Yes         No
# Just Shawarma                                               Yes         No
# Biggies Burger 'n' More                                     Yes         No
# Mojo Pizza - 2X Toppings                                    Yes         No
# ...                                                         ...        ...
# Izakaya Gastro Pub                                          Yes        Yes
# M Bar - Bengaluru Marriott Hotel Whitefield                  No         No
# Keys Cafe - Keys Hotel                                       No         No
# Bhagini                                                      No         No
# Chime - Sheraton Grand Bengaluru Whitefield Hot...           No        Yes
#
#                                                     rate  votes  \
# name
# Beijing Bites                                        3.7    679
# BOX8- Desi Meals                                     4.1    340
# Just Shawarma                                        3.9    160
# Biggies Burger 'n' More                              3.6     58
# Mojo Pizza - 2X Toppings                             4.2    179
# ...                                                  ...    ...
# Izakaya Gastro Pub                                   3.8    128
# M Bar - Bengaluru Marriott Hotel Whitefield          3.9     77
# Keys Cafe - Keys Hotel                               2.8    161
# Bhagini                                              2.5     81
# Chime - Sheraton Grand Bengaluru Whitefield Hot...   4.3    236
#
#                                                                       location  \
# name
# Beijing Bites                                             Rajarajeshwari Nagar
# BOX8- Desi Meals                                                  Banashankari
# Just Shawarma                                               Kumaraswamy Layout
# Biggies Burger 'n' More                                     Kumaraswamy Layout
# Mojo Pizza - 2X Toppings                                          Banashankari
# ...                                                                        ...
# Izakaya Gastro Pub                                                  Whitefield
# M Bar - Bengaluru Marriott Hotel Whitefield                         Whitefield
# Keys Cafe - Keys Hotel                                              Whitefield
# Bhagini                                                             Whitefield
# Chime - Sheraton Grand Bengaluru Whitefield Hot...  ITPL Main Road, Whitefield
#
#                                                              rest_type  \
# name
# Beijing Bites                                            Casual Dining
# BOX8- Desi Meals                                    Takeaway, Delivery
# Just Shawarma                                              Quick Bites
# Biggies Burger 'n' More                                    Quick Bites
# Mojo Pizza - 2X Toppings                                      Delivery
# ...                                                                ...
# Izakaya Gastro Pub                                  Bar, Casual Dining
# M Bar - Bengaluru Marriott Hotel Whitefield           Fine Dining, Bar
# Keys Cafe - Keys Hotel                              Casual Dining, Bar
# Bhagini                                             Casual Dining, Bar
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                 Bar
#
#                                                                                            dish_liked  \
# name
# Beijing Bites                                       Momos, Dragon Chicken, Hakka Noodles, Chowmein...
# BOX8- Desi Meals                                    Paratha, Mughlai Chicken, Masala Lemonade, But...
# Just Shawarma                                                              Whole Meat Shawarma, Fries
# Biggies Burger 'n' More                                        Burgers, Fries, Mojito, Chicken Burger
# Mojo Pizza - 2X Toppings                            Veggie Pizza, Garlic Bread, Lava Cake, Chocola...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# M Bar - Bengaluru Marriott Hotel Whitefield                                          Rooftop Ambience
# Keys Cafe - Keys Hotel                              Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# Bhagini                                                                          Biryani, Andhra Meal
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                       Cocktails, Pizza, Buttermilk
#
#                                                          cuisines  \
# name
# Beijing Bites                                       Chinese, Thai
# BOX8- Desi Meals                                           others
# Just Shawarma                                             Arabian
# Biggies Burger 'n' More                                    others
# Mojo Pizza - 2X Toppings                                    Pizza
# ...                                                           ...
# Izakaya Gastro Pub                                         others
# M Bar - Bengaluru Marriott Hotel Whitefield           Finger Food
# Keys Cafe - Keys Hotel                                     others
# Bhagini                                                    others
# Chime - Sheraton Grand Bengaluru Whitefield Hot...    Finger Food
#
#                                                     approx_cost(for two people)  \
# name
# Beijing Bites                                                             850.0
# BOX8- Desi Meals                                                          500.0
# Just Shawarma                                                             300.0
# Biggies Burger 'n' More                                                   650.0
# Mojo Pizza - 2X Toppings                                                  600.0
# ...                                                                         ...
# Izakaya Gastro Pub                                                       1200.0
# M Bar - Bengaluru Marriott Hotel Whitefield                              2000.0
# Keys Cafe - Keys Hotel                                                   1200.0
# Bhagini                                                                   800.0
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                       2500.0
#
#                                                                                          reviews_list  \
# name
# Beijing Bites                                       rated 30 ratedn iãx83ãx83ãx82ãx82ãx83ãx8...
# BOX8- Desi Meals                                    rated 40 ratedn recently one industrial visit ...
# Just Shawarma                                       rated 40 ratedn small place sharma delicious t...
# Biggies Burger 'n' More                             rated 50 ratedn potato crunch burger biggies c...
# Mojo Pizza - 2X Toppings                            rated 50 ratedn delivery time even rush hoursn...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  rated 30 ratedn nice place hangout kids one pa...
# M Bar - Bengaluru Marriott Hotel Whitefield         rated 40 ratedn went post dinner dessert smoot...
# Keys Cafe - Keys Hotel                              rated 30 ratedn place good great food good spi...
# Bhagini                                             rated 40 ratedn fine place chill office hours ...
# Chime - Sheraton Grand Bengaluru Whitefield Hot...  rated 40 ratedn nice friendly place staff awes...
#
#                                                    menu_item listed_in(type)  \
# name
# Beijing Bites                                             []        Delivery
# BOX8- Desi Meals                                          []        Delivery
# Just Shawarma                                             []        Delivery
# Biggies Burger 'n' More                                   []        Delivery
# Mojo Pizza - 2X Toppings                                  []        Delivery
# ...                                                      ...             ...
# Izakaya Gastro Pub                                        []   Pubs and bars
# M Bar - Bengaluru Marriott Hotel Whitefield               []   Pubs and bars
# Keys Cafe - Keys Hotel                                    []   Pubs and bars
# Bhagini                                                   []   Pubs and bars
# Chime - Sheraton Grand Bengaluru Whitefield Hot...        []   Pubs and bars
#
#                                                    listed_in(city)
# name
# Beijing Bites                                         Banashankari
# BOX8- Desi Meals                                      Banashankari
# Just Shawarma                                         Banashankari
# Biggies Burger 'n' More                               Banashankari
# Mojo Pizza - 2X Toppings                              Banashankari
# ...                                                            ...
# Izakaya Gastro Pub                                      Whitefield
# M Bar - Bengaluru Marriott Hotel Whitefield             Whitefield
# Keys Cafe - Keys Hotel                                  Whitefield
# Bhagini                                                 Whitefield
# Chime - Sheraton Grand Bengaluru Whitefield Hot...      Whitefield
#
# [4615 rows x 14 columns]

# %%
df_zomato = df_zomato.rename(columns={'approx_cost(for two people)':'cost'})

# %%
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_zomato['reviews_list'])

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def recommend(name, cosine_similarities = cosine_similarities):
   
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    idx = indices[indices == name].index[0]
    
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_zomato.index)[each])
    
    # Creating the new data set to show similar restaurants
    df_new = pd.DataFrame(columns=['cuisines', 'rate', 'cost'])
    
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:
        df_new = df_new.append(pd.DataFrame(df_zomato[['cuisines','rate', 'cost']][df_zomato.index == each].sample()))
    
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['cuisines','rate', 'cost'], keep=False)
    df_new = df_new.sort_values(by='rate', ascending=False).head(10)
    
    print('TOP %s RESTAURANTS LIKE %s WITH SIMILAR REVIEWS: ' % (str(len(df_new)), name))
    
    return df_new

# %%
df_zomato['name'] = df_zomato.index

# %%
df_zomato.loc['Jalsa'][:1]

# %%
recommend('Jalsa')

# %% [markdown]
# # NOW USING THIS CONTENT BASED MODEL TO FIND SEARCH QUERY BASED RECOMMENDATIONS

# %%
df_zomato = df_zomato.append({"reviews_list": "dosa","name":"thisisuser"}, ignore_index=True)

# %%
# Creating tf-idf matrix
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_zomato['reviews_list'])

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def recommend(location,cosine_similarities = cosine_similarities):
   
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    idx = df_zomato[df_zomato['name'] == "thisisuser"].index[0]
    
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_zomato.index)[each])
    
    # Creating the new data set to show similar restaurants
    df_new = pd.DataFrame(columns=['name','cuisines', 'rate', 'cost','location'])
    
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:
        df_new = df_new.append(pd.DataFrame(df_zomato[['name','cuisines','rate', 'cost','location']][df_zomato.index == each].sample()))
    
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['name','cuisines','rate', 'cost','location'], keep=False)
    df_new = df_new.sort_values(by='rate', ascending=False).head(30)
    df_new = df_new[df_new['location'] == location]
    
    return df_new

# %%
recommend('Jayanagar')

# %%
df_zomato = df_zomato[df_zomato['name']!="thisisuser"]
